# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
df_advert  = pd.read_csv("C:/Users/hp/Documents/data/ADVERTISING/Advertising.csv")
df_advert.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df_advert.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
df_advert.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
df_advert.drop(["Unnamed: 0"], axis="columns", inplace=True)

# %%
df_advert.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
sns.regplot(data=df_advert, x="TV", y="sales")
plt.title("Regression plot for sales vs TV")
plt.show()

# %%
sns.regplot(data=df_advert, x="radio", y="sales")
plt.title("Regression plot for sales vs radio")
plt.show()

# %%
sns.regplot(data=df_advert, x="newspaper", y="sales")
plt.title("Regression plot for sales vs newspaper")
plt.show()

# %%
df_advert.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(df_advert.corr(), annot=True)
plt.show()

# %% [markdown]
# ### TV and Sales are highly correlated, the more the product is being advertise on TV the higher  the sales of the product

# %% [markdown]
# ### The fastest means of advertisement out of TV, radio, newspaper that gives highest sales based on the given data is TV
#  #### For this reason TV should be consider for advertising the product to give effective sales of the product
